# %%
import pandas as pd

# Load data from a CSV file
df = pd.read_csv(r'C:\Users\hamza\Downloads\DEEP LEARNONG- BYTEWISE\cost-of-living - Copy77.csv')

# Print the first five rows of the DataFrame
print(df.head())
# Out:
#    Unnamed: 0      city      country    x1     x2    x3    x4    x5    x6  \
# 0           0     Delhi        India  4.90  22.04  4.28  1.84  3.67  1.78
# 1           1  Shanghai        China  5.59  40.51  5.59  1.12  4.19  3.96
# 2           2   Jakarta    Indonesia  2.54  22.25  3.50  2.02  3.18  2.19
# 3           3    Manila  Philippines  3.54  27.40  3.54  1.24  1.90  2.91
# 4           4     Seoul  South Korea  7.16  52.77  6.03  3.02  4.52  3.86
#
#      x7  ...     x47      x48     x49      x50      x51       x52       x53  \
# 0  0.48  ...   36.26   223.87  133.38   596.16   325.82   2619.46   1068.90
# 1  0.52  ...  121.19  1080.07  564.30  2972.57  1532.23  17333.09   9174.88
# 2  0.59  ...   80.32   482.85  270.15  1117.69   584.37   2694.05   1269.44
# 3  0.93  ...   61.82   559.52  281.78  1754.40   684.81   3536.04   2596.44
# 4  1.46  ...  108.30   809.83  583.60  2621.05  1683.74  21847.94  10832.90
#
#        x54   x55  data_quality
# 0   586.35  7.96             1
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0       city        country     x1     x2    x3    x4    x5  \
# 0             0      Delhi          India   4.90  22.04  4.28  1.84  3.67
# 1             1   Shanghai          China   5.59  40.51  5.59  1.12  4.19
# 2             2    Jakarta      Indonesia   2.54  22.25  3.50  2.02  3.18
# 3             3     Manila    Philippines   3.54  27.40  3.54  1.24  1.90
# 4             4      Seoul    South Korea   7.16  52.77  6.03  3.02  4.52
# ..          ...        ...            ...    ...    ...   ...   ...   ...
# 215         215     Havana           Cuba  10.00  40.00  7.00  2.50  3.00
# 216         216     Ningbo          China   4.54  23.05  5.45  0.56  4.19
# 217         217  Riverside  United States  17.00  70.00  8.00  7.00  5.50
# 218         218  Baltimore  United States  14.50  65.00  9.00  5.50  8.00
# 219         219   Portland  United States  16.00  75.00  8.00  6.00  7.00
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0          x1          x2          x3          x4          x5  \
# count  220.000000  211.000000  214.000000  218.000000  205.000000  206.000000
# mean   109.500000    6.103886   32.534393    5.594725    2.484878    3.519612
# std     63.652704    5.401638   22.181264    1.962466    2.077438    2.036351
# min      0.000000    0.790000    5.560000    2.060000    0.420000    0.870000
# 25%     54.750000    2.790000   18.025000    4.190000    0.880000    2.100000
# 50%    109.500000    3.670000   22.605000    4.895000    1.810000    2.800000
# 75%    164.250000    6.990000   39.655000    6.507500    3.020000    4.262500
# max    219.000000   25.000000  100.000000   12.000000   12.250000   13.540000
#
#                x6          x7          x8          x9  ...         x47  \
# count  217.000000  219.000000  217.000000  216.000000  ...  209.000000
# mean     2.909724    0.875616    0.617419    1.480556  ...   80.128325
# ...

# %%
# Load data from a JSON file
# df = pd.read_json('__.json')

# Load data from an Excel file
# df = pd.read_excel('__.xls')

# %%
import pandas as pd
from sqlite3 import connect

# %%
conn = connect("stocks.db")
data = pd.read_csv("cost-of-living - Copy77.csv")
data.to_sql("neww",conn)
df = pd.read_sql("SELECT * FROM neww LIMIT 5",conn)
print(df)
# Out:
#    index  Unnamed: 0      city      country    x1     x2    x3    x4    x5  \
# 0      0           0     Delhi        India  4.90  22.04  4.28  1.84  3.67
# 1      1           1  Shanghai        China  5.59  40.51  5.59  1.12  4.19
# 2      2           2   Jakarta    Indonesia  2.54  22.25  3.50  2.02  3.18
# 3      3           3    Manila  Philippines  3.54  27.40  3.54  1.24  1.90
# 4      4           4     Seoul  South Korea  7.16  52.77  6.03  3.02  4.52
#
#      x6  ...     x47      x48     x49      x50      x51       x52       x53  \
# 0  1.78  ...   36.26   223.87  133.38   596.16   325.82   2619.46   1068.90
# 1  3.96  ...  121.19  1080.07  564.30  2972.57  1532.23  17333.09   9174.88
# 2  2.19  ...   80.32   482.85  270.15  1117.69   584.37   2694.05   1269.44
# 3  2.91  ...   61.82   559.52  281.78  1754.40   684.81   3536.04   2596.44
# 4  3.86  ...  108.30   809.83  583.60  2621.05  1683.74  21847.94  10832.90
#
#        x54   x55  data_quality
# ...
